# %%
#hello world program
print("="*27)
print("WELCOME TO MY PROGRAM!!")
print("="*27)
# Out:
# ===========================
# WELCOME TO MY PROGRAM!!
# ===========================

# %%
#get user's name
name=input("Enter your name:")

#greet user using f-string whenever i want to include the name entered by the user
print(f"Hello,{name} !")
print(f"Nice to meet you,{name}.")
print("Hope your day was a bliss")
print("THANK YOU FOR USING MY PROGRAM!")
print("="*40)
# Out:
# Enter your name: natali
# Hello,natali !
# Nice to meet you,natali.
# Hope your day was a bliss
# THANK YOU FOR USING MY PROGRAM!
# ========================================
